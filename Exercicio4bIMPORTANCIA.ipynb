# %% [markdown]
# <a href="https://colab.research.google.com/github/jpengtelecom/Lista_02_11-04-2024/blob/main/Exercicio4bIMPORTANCIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 1000000
#gerar N amostras uniformes
y = np.random.uniform(0, 1, N)
#Gerar as amostras de g(x)
A = 1/(np.exp(3) - np.exp(-1))
ygx = np.log(y/A + (np.exp(-1))) -1

#calcular a integral
integral = np.sum((np.exp(ygx + ygx**2)) /(A*np.exp(ygx+1))) / N
print(f'Integral = {integral:.4f}')
#plotar o grafico
x = np.linspace(-2, 2, N)
curve_y = np.exp((x + x**2))
plt.plot(x, curve_y, color='black')
plt.fill_between(x, curve_y, color='blue')
plt.text(-1, 200, f'Area = {integral:.4f}', fontsize=14, color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Integral = 92.9965
