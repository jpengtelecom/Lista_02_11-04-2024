# %% [markdown]
# <a href="https://colab.research.google.com/github/jpengtelecom/Lista_02_11-04-2024/blob/main/Exercicio04bMonteCarlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib

# %% [markdown]
# a = -2; b = 2
# y = (x -a)/(b-a), logo x = 4y - 2
# dy = dx / (b-a), logo 4dy = dx

# %%
import numpy as np
import matplotlib.pyplot as plt

N=1000000
y=np.random.uniform(0,1,N)
x = 4*y - 2
integral=4*sum(np.exp((x+x**2)))/N
print(integral)
# Out:
# 93.24518992338989

# %%
# Define the function
def f(x):
  return np.exp((x + x**2))

# Create the x-axis values
x = np.linspace(-2, 2, 50)


# Plot the function
plt.plot(x, f(x))

# Fill the area under the curve
plt.fill_between(x, f(x), color='lightblue')

# Add the label with the area value
plt.text(-1, 250,f'Area = {integral:.3f}', fontsize=14)

# Add labels and title
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of exp((x + x**2)) with Area Label')

# Show the plot
plt.show()
